# %% [markdown]
# # Chapter 4
#
#
# - Correlación
# - Advertencias sobre la correlación
# - Diseño de experimentos

# %% [markdown]
# ## Adivina la correlación
# A la derecha, utiliza el diagrama de dispersión para estimar cuál es la correlación entre las variables x e y. Una vez que lo hayas adivinado, utiliza el botón New Plot para probar algunos diagramas de dispersión más. Contesta a la pregunta de abajo para continuar con el siguiente ejercicio.
#
# ¿Cuál de las siguientes afirmaciones sobre la correlación NO es verdadera ?
#
# ![image.png](attachment:image.png)
#
# ### Instrucciones
#
# - [ ] Si la correlación entre x e y tiene una magnitud elevada, los puntos de datos se agruparán estrechamente alrededor de una línea.
# - [ ] La correlación puede escribirse como r.
# - [ ] Si x e y están correlacionados negativamente, los valores de y disminuyen a medida que aumentan los de x.
# - [x] La correlación no puede ser 0.
#
#
# > **Note:** Cuando la correlación es 0, eso significa que no hay relación entre dos variables y los puntos parecen estar dispersos al azar.

# %% [markdown]
# ## Relaciones entre variables
# En este capítulo, trabajarás con un conjunto de datos world_happiness que contiene los resultados de 2019 World Happiness Report. El informe puntúa a diferentes países en función de lo felices que son sus habitantes. También clasifica a cada país en función de diversos aspectos sociales, como el apoyo social, la libertad, la corrupción y otros. El conjunto de datos también incluye el PIB per cápita y la esperanza de vida de cada país.
#
# En este ejercicio, examinarás la relación entre la esperanza de vida de un país (life_exp) y la puntuación de felicidad (happiness_score) tanto visual como cuantitativamente. Se ha cargado seaborn como sns, matplotlib.pyplot como plt y pandas como pd, y tienes world_happiness disponible.
#
# ### Instrucciones 1/4
#
# Crea un diagrama de dispersión de happiness_score frente a life_exp (sin línea de tendencia) utilizando seaborn.
# Muestra el gráfico.

# %%
# Create a scatterplot of happiness_score vs. life_exp and show
sns.scatterplot(x='life_exp', y='happiness_score', data=world_happiness)

# Show plot
plt.show()

# %% [markdown]
# ### Instrucciones 2/4
#
# Crea un diagrama de dispersión de happiness_score frente a life_exp con una línea de tendencia lineal. Para ello, utiliza seaborn y establece ci en None.
# Muestra el gráfico.

# %%
# Create scatterplot of happiness_score vs life_exp with trendline
sns.lmplot(x='life_exp', y='happiness_score', data=world_happiness, ci=None)

# Show plot
plt.show()

# %% [markdown]
# ### Instrucciones 3/4
#
# **Pregunta**
# Según el diagrama de dispersión, ¿cuál es la correlación más probable entre life_exp y happiness_score?
#
# ![image.png](attachment:image.png)
#
# Respuestas posibles
#
# - [ ] 0,3
# - [ ] −0,3
# - [x] 0,8
# - [ ] −0,8

# %% [markdown]
# ### Instrucciones 4/4
#
# Calcula la correlación entre life_exp y happiness_score. Guárdalo como cor.

# %%
# Create scatterplot of happiness_score vs life_exp with trendline
sns.lmplot(x='life_exp', y='happiness_score', data=world_happiness, ci=None)

# Show plot
plt.show()

# Correlation between life_exp and happiness_score
cor = world_happiness['life_exp'].corr(world_happiness['happiness_score'])

print(cor)

# %% [markdown]
# > **Note:** Los diagramas de dispersión con líneas de tendencia son una excelente manera de verificar que una relación entre dos variables es realmente lineal.

# %% [markdown]
# ## ¿Qué no puede medir la correlación?
# Aunque el coeficiente de correlación es una forma cómoda de cuantificar la fuerza de una relación entre dos variables, dista mucho de ser perfecto. En este ejercicio, explorarás una de las advertencias del coeficiente de correlación al examinar la relación entre el PIB per cápita de un país (gdp_per_cap) y la puntuación de felicidad.
#
# Se ha importado pandas como pd, matplotlib.pyplot como plt y seaborn como sns, y se ha cargado world_happiness.
#
# ### Instrucciones 1/3
#
# Crea un diagrama de dispersión seaborn (sin línea de tendencia) que muestre la relación entre gdp_per_cap (en el eje X) y life_exp (en el eje Y).
# Muestra el gráfico

# %%
# Scatterplot of gdp_per_cap and life_exp
sns.scatterplot(x='gdp_per_cap', y='life_exp', data=world_happiness)

# Show plot
plt.show()

# %% [markdown]
# ### Instrucciones 2/3
#
# Calcula la correlación entre gdp_per_cap y life_exp y guárdala como cor.

# %%
# Scatterplot of gdp_per_cap and life_exp
sns.scatterplot(x='gdp_per_cap', y='life_exp', data=world_happiness)

# Show plot
plt.show()
  
# Correlation between gdp_per_cap and life_exp
cor = world_happiness['gdp_per_cap'].corr(world_happiness['life_exp'])

print(cor)

# %% [markdown]
# ### Instrucciones 3/3
#
# **Pregunta**
# La correlación entre el PIB per cápita y la esperanza de vida es de 0,7. ¿Por qué la correlación no es la mejor forma de medir la relación entre estas dos variables?
#
# ![image.png](attachment:image.png)
#
# **Respuestas posibles**
#
# - [ ] La correlación mide cómo afecta una variable a otra.
# - [x] La correlación solo mide las relaciones lineales.
# - [ ] La correlación no puede medir adecuadamente las relaciones entre variables numéricas.

# %% [markdown]
# ## Transformación de variables
# Cuando las variables tienen distribuciones sesgadas, a menudo requieren una transformación para formar una relación lineal con otra variable, de modo que pueda calcularse la correlación. En este ejercicio realizarás una transformación.
#
# Se ha importado pandas como pd, numpy como np, matplotlib.pyplot como plt y seaborn como sns, y se ha cargado world_happiness.
#
# ### Instrucciones 1/2
#
# Crea un diagrama de dispersión de happiness_score frente a gdp_per_cap y calcula la correlación entre ambos.

# %%
# Scatterplot of happiness_score vs. gdp_per_cap
sns.scatterplot(x='gdp_per_cap', y='happiness_score', data=world_happiness)
plt.show()

# Calculate correlation
cor = world_happiness['gdp_per_cap'].corr(world_happiness['happiness_score'])
print(cor)

# %% [markdown]
# ### Instrucciones 2/2
#
# Añade una nueva columna a world_happiness llamada log_gdp_per_cap que contenga el logaritmo de gdp_per_cap.
# Crea un diagrama de dispersión seaborn de happiness_score frente a log_gdp_per_cap.
# Calcula la correlación entre log_gdp_per_cap y happiness_score.

# %%
# Create log_gdp_per_cap column
world_happiness['log_gdp_per_cap'] = np.log(world_happiness['gdp_per_cap'])
# Scatterplot of happiness_score vs. log_gdp_per_cap
sns.scatterplot(x='log_gdp_per_cap', y='happiness_score', data=world_happiness)
plt.show()

# Calculate correlation
cor = world_happiness['log_gdp_per_cap'].corr(world_happiness['happiness_score'])
print(cor)

# %% [markdown]
# - **Sin Transformacion**
# ![image-2.png](attachment:image-2.png)
#
# - **Con Transformacion LOG**
# ![image.png](attachment:image.png)
#
# > **Note:** La relación entre el PIB per cápita y la felicidad se volvió más lineal al aplicar una transformación logarítmica. Las transformaciones logarítmicas son excelentes para usar en variables con una distribución sesgada, como el PIB.

# %% [markdown]
# ## ¿El azúcar aumenta la felicidad?
# Se ha añadido una nueva columna a world_happiness llamada grams_sugar_per_day, que contiene la cantidad media de azúcar ingerida por persona y día en cada país. En este ejercicio, examinarás el efecto del consumo medio de azúcar de un país en su puntuación de felicidad.
#
# Se ha importado pandas como pd, matplotlib.pyplot como plt y seaborn como sns, y se ha cargado world_happiness.
#
# ### Instrucciones 1/2
#
# Crea un diagrama de dispersión seaborn que muestre la relación entre grams_sugar_per_day (en el eje X) y happiness_score (en el eje Y).
# Calcula la correlación entre grams_sugar_per_day y happiness_score.

# %%
# Scatterplot of grams_sugar_per_day and happiness_score
sns.scatterplot(x='grams_sugar_per_day', y='happiness_score', data=world_happiness)
plt.show()

# Correlation between grams_sugar_per_day and happiness_score
cor = world_happiness['grams_sugar_per_day'].corr(world_happiness['happiness_score'])
print(cor)

# %% [markdown]
# ### Instrucciones 2/2
#
# **Pregunta**
# Según estos datos, ¿qué afirmación sobre el consumo de azúcar y las puntuaciones de felicidad es cierta?
#
# ![image.png](attachment:image.png)
#
# **Respuestas posibles**
#
# - [ ] Un mayor consumo de azúcar conduce a una mayor puntuación de felicidad.
# - [ ] A menor consumo de azúcar, menor puntuación de felicidad.
# - [x] Un mayor consumo de azúcar se asocia a una mayor puntuación de felicidad.
# - [ ] El consumo de azúcar no está relacionado con la felicidad.

# %% [markdown]
# ## Factores de confusión
# Un estudio investiga la relación entre la residencia en el vecindario y la capacidad pulmonar. Los investigadores miden la capacidad pulmonar de treinta personas del vecindario A, situado cerca de una autovía, y de treinta personas del vecindario B, que no está cerca de una autovía. Ambos grupos tienen unos hábitos de consumo de tabaco y un desglose similar por sexo.
#
# **¿Cuál de los siguientes podría ser un factor de confusión en este estudio?**
#
# ### Responder a la pregunta
#
# Respuestas posibles
# Selecciona una respuesta
#
# - [ ] Capacidad pulmonar
# - [ ] Vecindario
# - [x] Contaminación atmosférica
# - [ ] Condición de fumador
# - [ ] Sexo
#
# > **Note:** Es de esperar que haya más contaminación atmosférica en el vecindario situado cerca de la autovía, lo que puede provocar una menor capacidad pulmonar.

# %% [markdown]
# ## Tipos de estudio
# Aunque los experimentos controlados son ideales, muchas situaciones y preguntas de investigación no son propicias para un experimento controlado. En un experimento controlado, es probable que pueda inferirse la causalidad si los grupos de control y de prueba tienen características similares y no hay ninguna diferencia sistemática entre ellos. Por otra parte, la causalidad no suele inferirse de los estudios observacionales, cuyos resultados suelen interpretarse erróneamente como consecuencia de ello.
#
# En este ejercicio, practicarás la distinción entre experimentos controlados y estudios observacionales.
#
# ### Instrucciones
#
# Determina si cada estudio es un experimento controlado o un estudio observacional.

# %% [markdown]
# ### Respuestas
# - Experimento controlado
#     - Se comparan los síntomas de asma entre los niños asignados aleatoriamente a recibir servicios profesionales de control de plagas a domicilio o educación sobre el control de plagas.
#     - Se comparan las tasas de compra entre los usuarios de un sitio de comercio electrónico que son dirigidos aleatoriamente a una nueva versión de la página de inicio o a una versión antigua.
#     - Se asigna aleatoriamente a los sujetos una dieta y se compara la pérdida de peso.
# - Estudio observacional
#     - Hace una semana, se actualizó la página de inicio de un sitio de comercio electrónico. Las tasas de compra se comparan entre los usuarios que vieron las versiones antigua y nueva de la página de inicio.
#     - Se compara la prevalencia de enfermedades cardiacas entre veteranos con TEPT y veteranos sin TEPT.

# %% [markdown]
# ## Estudios longitudinales frente a estudios transversales
# Una empresa fabrica termómetros y quiere estudiar la relación entre la antigüedad de un termómetro y su exactitud. Para ello, toman una muestra de 100 termómetros diferentes de distintas antigüedades y comprueban su exactitud. ¿Son datos longitudinales o transversales?
#
# ### Responder a la pregunta
#
# **Respuestas posibles**
# Selecciona una respuesta
#
# - [ ] Longitudinal
# - [x] Transversal
# - [ ] Ambos
# - [ ] Ninguna
